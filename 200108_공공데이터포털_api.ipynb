# %% [markdown]
# ## 개발 계정 일반 인증키
# - end point
# - 데이터 포맷
# -  참고문서
# ## URL 입력 항목
# - 인증키
# - CURRENT_DATE
# - HOUR
# - COURSE_ID

# %% [markdown]
# ## URL 가져오기

# %%
my_key = "ZuZuvxFEu%2BfhX%2FiSOfgploZh7uZsex%2BAcbxaJywXZin23D6h4PCcASJrTdlypEdNjchPKKyZasuAVToOe8K%2BVg%3D%3D"

# %%
end_point = "http://apis.data.go.kr/B553077/api/open/sdsc/"
url1 = "storeZoneInRadius?radius=500&cx=127.004528&cy=37.567538&ServiceKey="
url2 = "&type=json"

url = end_point + url1 + my_key + url2
url
# Out:
# 'http://apis.data.go.kr/B553077/api/open/sdsc/storeZoneInRadius?radius=500&cx=127.004528&cy=37.567538&ServiceKey=ZuZuvxFEu%2BfhX%2FiSOfgploZh7uZsex%2BAcbxaJywXZin23D6h4PCcASJrTdlypEdNjchPKKyZasuAVToOe8K%2BVg%3D%3D&type=json'

# %%
import urllib.request

res = urllib.request.urlopen(url)
json_str = res.read().decode("utf-8")
json_str
# Out:
# '{\n\t"header" : {\n\t\t"description" : "소상공인시장진흥공단 주요상권"\n\t\t,"resultCode" : "00"\n\t\t,"resultMsg" : "NORMAL SERVICE"\n\t},\n\t"body" : {\n\t\t\t"items" : [\n\t\t\t\t{\n\t\t\t\t"trarNo" : 2207\n\t\t\t\t,"mainTrarNm" : "동대문역사문화공원역"\n\t\t\t\t,"ctprvnCd" : "11"\n\t\t\t\t,"ctprvnNm" : "서울특별시"\n\t\t\t\t,"signguCd" : "11140"\n\t\t\t\t,"signguNm" : "중구"\n\t\t\t\t,"trarArea" : 81499.1\n\t\t\t\t,"coordNum" : 8\n\t\t\t\t,"coords" : "POLYGON ((127.007565 37.565945, 127.004846 37.566394, 127.002877 37.566759, 127.002341 37.566737, 127.00252 37.5647, 127.004682 37.564852, 127.007062 37.564448, 127.007565 37.565945))"\n\t\t\t\t,"stdrDt" : "2015-12-17"\n\t\t\t\t}\n\t\t\t\t,{\n\t\t\t\t"trarNo" : 2214\n\t\t\t\t,"mainTrarNm" : "을지로4가역"\n\t\t\t\t,"ctprvnCd" : "11"\n\t\t\t\t,"ctprvnNm" : "서울특별시"\n\t\t\t\t,"signguCd" : "11140"\n\t\t\t\t,"signguNm" : "중구"\n\t\t\t\t,"trarArea" : 88434.9\n\t\t\t\t,"coordNum" : 8\n\t\t\t\t,"coords" : "POLYGON ((126.999081 37.566789, 127.002102 37.566937, 127.001981 37.568
# ...

# %% [markdown]
# ## json 형태로 변환, DataFrame 형태로 변환

# %%
import json
json_object = json.loads(json_str)
json_object

# %%
import pandas as pd
from pandas.io.json import json_normalize

body = [json_object['body']['items']]

# %%
table = json_normalize(json_object['body']['items'])
table

# %% [markdown]
# # 상권정보 업종 소분류

# %%
URL = "http://apis.data.go.kr/B553077/api/open/sdsc/smallUpjongList?serviceKey=ZuZuvxFEu%2BfhX%2FiSOfgploZh7uZsex%2BAcbxaJywXZin23D6h4PCcASJrTdlypEdNjchPKKyZasuAVToOe8K%2BVg%3D%3D&indsLclsCd=Q&indsMclsCd=Q01"

# %%
url2 = "&type=json"

# %%
url = URL + url2

# %%
import urllib.request
import json
import pandas as pd
from pandas.io.json import json_normalize

response = urllib.request.urlopen(url)
json_str = response.read().decode("utf-8")
json_str
# Out:
# '{\n\t"header" : {\n\t\t"description" : "소상공인시장진흥공단 상권정보 업종소분류 코드"\n\t\t,"columns" : ["상권업종대분류코드","상권업종대분류코드명","상권업종중분류코드","상권업종중분류코드명","상권업종소분류코드","상권업종소분류코드명","데이터기준일자"]\n\t\t,"resultCode" : "00"\n\t\t,"resultMsg" : "NORMAL SERVICE"\n\t},\n\t"body" : {\n\t\t\t"items" : [\n\t\t\t\t{\n\t\t\t\t"indsLclsCd" : "Q"\n\t\t\t\t,"indsLclsNm" : "음식"\n\t\t\t\t,"indsMclsCd" : "Q01"\n\t\t\t\t,"indsMclsNm" : "한식"\n\t\t\t\t,"indsSclsCd" : "Q01A02"\n\t\t\t\t,"indsSclsNm" : "갈비/삼겹살"\n\t\t\t\t,"stdrDt" : "2015-12-17"\n\t\t\t\t}\n\t\t\t\t,{\n\t\t\t\t"indsLclsCd" : "Q"\n\t\t\t\t,"indsLclsNm" : "음식"\n\t\t\t\t,"indsMclsCd" : "Q01"\n\t\t\t\t,"indsMclsNm" : "한식"\n\t\t\t\t,"indsSclsCd" : "Q01A03"\n\t\t\t\t,"indsSclsNm" : "곱창/양구이전문"\n\t\t\t\t,"stdrDt" : "2015-12-17"\n\t\t\t\t}\n\t\t\t\t,{\n\t\t\t\t"indsLclsCd" : "Q"\n\t\t\t\t,"indsLclsNm" : "음식"\n\t\t\t\t,"indsMclsCd" : "Q01"\n\t\t\t\t,"indsMclsNm" : "한식"\n\t\t\t\t,"indsSclsCd" : "Q01A21"\n\t\t\t\t,"indsSclsNm" : "기사식당"\n\t\t\t\t,"stdrDt" : "2015-12-17"\n\t\
# ...

# %%
json_object = json.loads(json_str)
json_object
# Out:
# {'header': {'description': '소상공인시장진흥공단 상권정보 업종소분류 코드',
#   'columns': ['상권업종대분류코드',
#    '상권업종대분류코드명',
#    '상권업종중분류코드',
#    '상권업종중분류코드명',
#    '상권업종소분류코드',
#    '상권업종소분류코드명',
#    '데이터기준일자'],
#   'resultCode': '00',
#   'resultMsg': 'NORMAL SERVICE'},
#  'body': {'items': [{'indsLclsCd': 'Q',
#     'indsLclsNm': '음식',
#     'indsMclsCd': 'Q01',
#     'indsMclsNm': '한식',
#     'indsSclsCd': 'Q01A02',
#     'indsSclsNm': '갈비/삼겹살',
#     'stdrDt': '2015-12-17'},
#    {'indsLclsCd': 'Q',
#     'indsLclsNm': '음식',
#     'indsMclsCd': 'Q01',
#     'indsMclsNm': '한식',
#     'indsSclsCd': 'Q01A03',
#     'indsSclsNm': '곱창/양구이전문',
#     'stdrDt': '2015-12-17'},
#    {'indsLclsCd': 'Q',
#     'indsLclsNm': '음식',
#     'indsMclsCd': 'Q01',
#     'indsMclsNm': '한식',
#     'indsSclsCd': 'Q01A21',
#     'indsSclsNm': '기사식당',
#     'stdrDt': '2015-12-17'},
#    {'indsLclsCd': 'Q',
#     'indsLclsNm': '음식',
#     'indsMclsCd': 'Q01',
#     'indsMclsNm': '한식',
#     'indsSclsCd': 'Q01A99',
# ...

# %%
body = [json_object['body']['items']]
table = json_normalize(json_object['body']['items'])
table
# Out:
#    indsLclsCd indsLclsNm indsMclsCd indsMclsNm indsSclsCd indsSclsNm  \
# 0           Q         음식        Q01         한식     Q01A02     갈비/삼겹살
# 1           Q         음식        Q01         한식     Q01A03   곱창/양구이전문
# 2           Q         음식        Q01         한식     Q01A21       기사식당
# 3           Q         음식        Q01         한식     Q01A99     기타고기요리
# 4           Q         음식        Q01         한식     Q01A19        냉면집
# 5           Q         음식        Q01         한식     Q01A06  돌솥/비빕밥전문점
# 6           Q         음식        Q01         한식     Q01A11     두부요리전문
# 7           Q         음식        Q01         한식     Q01A17      버섯전문점
# 8           Q         음식        Q01         한식     Q01A16      보리밥전문
# 9           Q         음식        Q01         한식     Q01A07  부대찌개/섞어찌개
# 10          Q         음식        Q01         한식     Q01A09       설렁탕집
# 11          Q         음식        Q01         한식     Q01A15      순두부전문
# 12          Q         음식        Q01         한식     Q01A10       쌈밥전문
# ...
